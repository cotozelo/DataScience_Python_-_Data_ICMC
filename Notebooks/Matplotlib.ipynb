# %% [markdown]
# <a href="https://colab.research.google.com/github/cotozelo/DataScience_Python_-_Data_ICMC/blob/main/Notebooks/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib
#
# Exemplos de uso da biblioteca...
# ref https://matplotlib.org/stable/index.html

# %% [markdown]
# ##Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exemplos .plot

# %% [markdown]
# ### Dados

# %%
empresa_a = [1000, 1500, 1200, 3000, 2100, 2000]
empresa_b = [750, 2300, 1000, 500, 1200, 1500]

# %% [markdown]
# ### Gráfico simples

# %%
#Grafico simples
plt.plot(empresa_a)
#ref https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot

# %% [markdown]
# ### Figurando o tampo do gráfico

# %%
#figsize=(largura, altura)
plt.figure(figsize=(10, 6))
plt.plot(empresa_a); #; retira a linha de informação [<matplotlib.lines.Line2D at 0x7f84652f4dd0>]

# %% [markdown]
# ### Aplicando marcações nos pontos

# %%
plt.figure(figsize=(10, 6))
plt.plot(empresa_a, marker="o"); 
# podemos usar varios tipos de marker, '-', '+', 'x', ...
# ref https://matplotlib.org/stable/api/markers_api.html?highlight=marker

# %% [markdown]
# ### Mudando o tipo de linha

# %%
plt.figure(figsize=(10, 6))
plt.plot(empresa_a, marker="o", linestyle='--'); 
#linestyle muda o tempo de linha, pode usar varios tipo, '--', '-'
# ref https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html?highlight=linestyle

# %% [markdown]
# ### Cor da linha

# %%
plt.figure(figsize=(10, 6))
plt.plot(empresa_a, marker="o", linestyle='--', color='green'); 
# color define direntes tipos de cores

# %% [markdown]
# ### Títulos

# %%
plt.figure(figsize=(10, 6))
plt.plot(empresa_a, '--o', color='green') # marker="o", linestyle='--' pode ser torcado por '--o'
plt.title("Lucro da empresa A")
plt.xlabel("Mês")
plt.ylabel("Valores em R$")
plt.show()

# %% [markdown]
# ### Duas linhas no mesmo gráfico

# %%
plt.figure(figsize=(10, 6))
plt.plot(empresa_a, '--o', color='green')
plt.plot(empresa_b, '-x', color='blue')
plt.title("Lucro das empresas A e B")
plt.xlabel("Mês")
plt.ylabel("Valores em R$")
plt.show()

# %% [markdown]
# ### Legenda
#
# ref https://matplotlib.org/stable/api/legend_api.html?highlight=legend#module-matplotlib.legend

# %%
plt.figure(figsize=(10, 6))
plt.plot(empresa_a, '--o', color='green', label='Empresa A')
plt.plot(empresa_b, '-x', color='blue', label='Empresa B')
plt.title("Lucro das empresas A e B")
plt.xlabel("Mês")
plt.ylabel("Valores em R$")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Dados

# %%
# Vamos carregar o conjunto de dados que vamos usar
df = pd.read_csv('penguins_size.csv')
df.head()
# Out:
#   species     island  culmen_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen              39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen              39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen              40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen              36.7  ...              193.0       3450.0  FEMALE
# 4  Adelie  Torgersen              39.3  ...              190.0       3650.0    MALE
#
# [5 rows x 7 columns]

# %% [markdown]
# ## Barra
#
# ref https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html?highlight=bar#matplotlib.pyplot.bar

# %%
altura = [10, 5, 6, 2, 7]
posicao = [1, 2, 3, 4, 5]
plt.bar(posicao, altura);
#plt.bar(x, y)

# %%
contagem = df['species'].value_counts()
contagem
# Out:
# Adelie       146
# Gentoo       120
# Chinstrap     68
# Name: species, dtype: int64

# %%
type(contagem)
# Out:
# pandas.core.series.Series

# %%
classes = list(contagem.index)
classes
# Out:
# ['Adelie', 'Gentoo', 'Chinstrap']

# %%
quantidade = list(contagem.values)
quantidade
# Out:
# [146, 120, 68]

# %%
plt.bar(classes, quantidade)
plt.show()

# %% [markdown]
# ##Histograma

# %%
plt.hist(df['culmen_length_mm']);

# %% [markdown]
# ###Config. tamanho dos intervalos

# %%
plt.hist(df['culmen_length_mm'], bins=50);
#bins fala a quantidade de barras

# %% [markdown]
# ## Scatterplot
#
# ref https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html?highlight=scatter#matplotlib.pyplot.scatter

# %% [markdown]
# ###Simples

# %%
plt.scatter(df['body_mass_g'], df['flipper_length_mm']);

# %% [markdown]
# ###Títulos

# %%
plt.scatter(df['body_mass_g'], df['flipper_length_mm'])
plt.xlabel('Massa corporal')
plt.ylabel('Tamanho das asas')
plt.title('Massa vs Asas')
plt.show()

# %% [markdown]
# ### Tamanho do gráfico

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['body_mass_g'], df['flipper_length_mm'])
plt.xlabel('Massa corporal')
plt.ylabel('Tamanho das asas')
plt.title('Massa vs Asas')
plt.show()

# %% [markdown]
# Nesse caso existe uma relação entre a massa corporal e o tamanho das asas, visto que pelo gráfico fica evidente que quanto maior a massa corporal maior as assas
